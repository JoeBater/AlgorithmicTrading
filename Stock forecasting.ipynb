# %% [markdown]
# # Stock forecasting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pandas_datareader as pdr
import datetime as dt

import mplfinance as mpf

# %%
start=dt.datetime(2021, 1, 1)
end=dt.datetime(2021,3,1)

# %%
gold = pdr.get_data_yahoo('GC=F', start=start, end=end)

# %%
silver = pdr.get_data_yahoo('SI=F', start=start, end=end)

# %%
gold
# Out:
#                    High          Low         Open        Close    Volume  \
# Date
# 2021-01-04  1945.099976  1912.199951  1912.199951  1944.699951     154.0
# 2021-01-05  1952.699951  1941.300049  1941.699951  1952.699951     113.0
# 2021-01-06  1959.900024  1901.500000  1952.000000  1906.900024     331.0
# 2021-01-07  1926.699951  1912.000000  1922.599976  1912.300049     122.0
# 2021-01-08  1908.000000  1834.099976  1908.000000  1834.099976      60.0
# 2021-01-11  1849.599976  1826.500000  1826.500000  1849.599976      20.0
# 2021-01-12  1859.699951  1839.400024  1849.000000  1842.900024     176.0
# 2021-01-13  1858.599976  1853.599976  1858.000000  1853.599976     189.0
# 2021-01-14  1850.699951  1836.699951  1836.699951  1850.300049     149.0
# 2021-01-15  1829.400024  1825.000000  1829.400024  1829.300049      31.0
# 2021-01-19  1842.900024  1802.000000  1802.000000  1839.500000      13.0
# 2021-01-20  1866.599976  1844.400024  1847.800049  1865.900024      16.0
# ...

# %%
gold['Close'].plot()

# %%
dirpath = r'C:\Users\joeba\OneDrive\Documents\ML\gold prices'
gold[['Close']].to_csv(dirpath+'/gold.csv')

# %%
silver['Close'].plot()

# %%
mpf.plot(gold,type='candle',style='yahoo',tight_layout=True)
