# %% [markdown]
# # gold prices
#
# use the yahoo finance API to get gold prices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import datetime as dt
from datetime import date
from datetime import timedelta

# %%
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()

# %%
start = '2021-01-01'
end = date.today() - timedelta(days = 1)
gold = pdr.get_data_yahoo('GC=F',start,end)
#silver = yf.download('SI=F',start,end)
#platinum = yf.download('PLG',start,end)

#gold = pd.read_csv(r'C:\Users\joeba\OneDrive\Documents\ML\gold prices\gold.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gold
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-01-04  1912.199951  1945.099976  1912.199951  1944.699951  1944.699951
# 2021-01-05  1941.699951  1952.699951  1941.300049  1952.699951  1952.699951
# 2021-01-06  1952.000000  1959.900024  1901.500000  1906.900024  1906.900024
# 2021-01-07  1922.599976  1926.699951  1912.000000  1912.300049  1912.300049
# 2021-01-08  1908.000000  1908.000000  1834.099976  1834.099976  1834.099976
# ...                 ...          ...          ...          ...          ...
# 2023-08-14  1909.300049  1912.599976  1903.300049  1910.599976  1910.599976
# 2023-08-15  1906.000000  1907.699951  1895.000000  1902.500000  1902.500000
# 2023-08-16  1904.500000  1904.500000  1890.300049  1896.099976  1896.099976
# 2023-08-17  1893.699951  1902.400024  1884.000000  1884.099976  1884.099976
# 2023-08-18  1891.800049  1891.800049  1886.099976  1886.099976  1886.099976
#
#             Volume
# Date
# 2021-01-04     154
# ...

# %%
gold['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
price = gold.tail(30).copy()
price
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-07-10  1923.599976  1926.099976  1912.300049  1925.000000  1925.000000
# 2023-07-11  1925.000000  1937.000000  1924.199951  1931.300049  1931.300049
# 2023-07-12  1932.300049  1958.000000  1932.199951  1956.199951  1956.199951
# 2023-07-13  1961.099976  1961.099976  1953.000000  1959.199951  1959.199951
# 2023-07-14  1958.400024  1960.599976  1952.699951  1960.099976  1960.099976
# 2023-07-17  1954.000000  1956.500000  1946.599976  1952.400024  1952.400024
# 2023-07-18  1968.800049  1978.400024  1963.400024  1977.199951  1977.199951
# 2023-07-19  1977.000000  1977.500000  1973.000000  1977.500000  1977.500000
# 2023-07-20  1973.699951  1973.699951  1965.599976  1968.300049  1968.300049
# 2023-07-21  1961.800049  1964.300049  1961.800049  1964.300049  1964.300049
# 2023-07-24  1965.300049  1965.500000  1960.300049  1960.300049  1960.300049
# ...

# %%
plt.figure(figsize=(16,6))

#mpf.plot(gold,type='candle',style='yahoo')

width = 0.4
width2 = 0.01

plt.plot(price['Close'], color='black', linestyle='--', alpha=0.5 )

up = price[price['Close'] >= price['Open']]
dn = price[price['Close'] < price['Open']]

rd = 'red'
gn = 'green'

# plot up prices
plt.bar(up.index, up.Close-up.Open, width, bottom=up.Open, color='green')
plt.bar(up.index, up.High-up.Close, width2, bottom=up.Open, color='green')
plt.bar(up.index, up.Low-up.Open, width2, bottom=up.Open, color='green')

# plot dn prices
plt.bar(dn.index, dn.Close-dn.Open, width, bottom=dn.Open, color='red')
plt.bar(dn.index, dn.High-dn.Close, width2, bottom=dn.Open, color='red')
plt.bar(dn.index, dn.Low-dn.Open, width2, bottom=dn.Open, color='red')

fst = price.index[0].strftime('%Y-%m-%d')
lst = price.index[-1].strftime('%Y-%m-%d')

plt.xticks(pd.date_range(fst, lst).tolist(), rotation='vertical')

plt.show()
